# %%
#======Core============
import pandas as pd
import numpy as np
import os
import torch

#======PyForecast======
from pytorch_forecasting import Baseline, NBeats, TimeSeriesDataSet
from pytorch_forecasting.data import NaNLabelEncoder
from pytorch_forecasting.data.examples import generate_ar_data
from pytorch_forecasting.metrics import SMAPE

#======PyLightning======
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping
from pytorch_lightning import Trainer
from pytorch_lightning.loggers import TensorBoardLogger

#======UEXP============
from ue.uexp.dataprocessing.processor_binance import BinanceProcessor
from ue.uexp.dataprocessing.func import *
from ue.uexp.dataprocessing.ta import *
from ue.uexp.models.util import *

import warnings
warnings.filterwarnings('ignore')

# %%
DEBUG = True

# %%
if DEBUG:
    df = pd.read_csv('one_day_test.csv')
else:
    ### get data (set config params)
    ticker_list = ["BTCUSDT"]
    start_date = "2021-12-30"
    end_date = "2021-12-31"
    time_interval = "1s"

    p = BinanceProcessor("binance")
    df = p.download_data(ticker_list, start_date, end_date, time_interval)
    
    ## process
    df.reset_index(inplace=True)
    df.rename(columns={'index':'time'}, inplace=True)
    df['time_idx'] = df.index
    df.drop(['open','high','low','volume', 'tic'], inplace=True, axis=1)
    df['series'] = 0
    df['time'] = pd.to_datetime(df['time'])
    
df.head()
# Out:
#                   time     close  time_idx  series
# 0  2021-12-30 00:00:00  46467.73         0       0
# 1  2021-12-30 00:00:01  46464.33         1       0
# 2  2021-12-30 00:00:02  46456.03         2       0
# 3  2021-12-30 00:00:03  46456.03         3       0
# 4  2021-12-30 00:00:04  46456.02         4       0

# %%
df['close'] = np.log(df['close']/df['close'].shift(1))

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                   time         close  time_idx  series
# 1  2021-12-30 00:00:01 -7.317173e-05         1       0
# 2  2021-12-30 00:00:02 -1.786476e-04         2       0
# 3  2021-12-30 00:00:03  0.000000e+00         3       0
# 4  2021-12-30 00:00:04 -2.152573e-07         4       0
# 5  2021-12-30 00:00:05  2.152573e-07         5       0

# %% [markdown]
# ## Train/val/test split

# %%
#80% used for train-val, (where val is only the last future_window datapoints)
df_train_val = df[:int(0.8*len(df))]
df_test = df[int(0.8*len(df)):]

# %% [markdown]
# # Timeseries Dataset

# %%
# define dataset: lookback 30 intervals, predict 10 into future

max_encoder_length = 30
max_prediction_length = 10
prediction_length = 60
ensure_pred_len = max_prediction_length + prediction_length
training_cutoff = df_train_val["time_idx"].max() - ensure_pred_len # this allows 60 predictions (given max_prediction_length is 10)
#said smt about at least back+forward lengths
training_cutoff
# Out:
# 138169

# %%
training = TimeSeriesDataSet(
    df_train_val[lambda x: x.time_idx <= training_cutoff],
    time_idx="time_idx",
    target="close",
    categorical_encoders={"series": NaNLabelEncoder().fit(df_train_val.series)},
    group_ids=["series"],
    # only unknown variable is "close" - and N-Beats can also not take any additional variables
    time_varying_unknown_reals=["close"],
    max_encoder_length=max_encoder_length,
    max_prediction_length=max_prediction_length,
    #allow_missing_timesteps=True,
)

# %%
validation = TimeSeriesDataSet.from_dataset(training, df_train_val, min_prediction_idx=training_cutoff + 1)
# ^ Generate dataset with different underlying data but same variable encoders and scalers, etc.

batch_size = 1024                     # NBEATS paper default
train_dataloader = training.to_dataloader(train=True, batch_size=batch_size, num_workers=0)
val_dataloader = validation.to_dataloader(train=False, batch_size=batch_size, num_workers=0)

# %%
df_test.head()
# Out:
#                        time         close  time_idx  series
# 138240  2021-12-31 14:24:00  0.000000e+00    138240       0
# 138241  2021-12-31 14:24:01 -2.088232e-07    138241       0
# 138242  2021-12-31 14:24:02 -3.797127e-04    138242       0
# 138243  2021-12-31 14:24:03 -1.568981e-04    138243       0
# 138244  2021-12-31 14:24:04 -1.395785e-04    138244       0

# %%
# testing dataset
testing = TimeSeriesDataSet(
    df_test,
    time_idx="time_idx",
    target="close",
    categorical_encoders={"series": NaNLabelEncoder().fit(df_test.series)},
    group_ids=["series"],
    # only unknown variable is "close" - and N-Beats can also not take any additional variables
    time_varying_unknown_reals=["close"],
    max_encoder_length=max_encoder_length,
    max_prediction_length=max_prediction_length,
    #allow_missing_timesteps=True,            # we have full data
)

# %%
#testingTSDS = TimeSeriesDataSet.from_dataset(testing, df_train_val, min_prediction_idx=training_cutoff + 1)

test_dataloader = testing.to_dataloader(train=False, batch_size=batch_size, num_workers=0)
# train=False allows it to do the prediction over all values...or smt
# see here: https://github.com/jdb78/pytorch-forecasting/issues/446

# %% [markdown]
# ## Experiment Name

# %%
exp_name = "{}_{}_of_{}_mel{}_mpl{}_for{}_{}".format(
        "2021-12-30", "2021-12-31", "BTCUSD", max_encoder_length, max_prediction_length,
        prediction_length, "logRet")
exp_name
# Out:
# '2021-12-30_2021-12-31_of_BTCUSD_mel30_mpl10_for60_logRet'

# %% [markdown]
# # Train Network
# using `generic` parameters

# %%
# GENERIC Params
params_generic = {
    "stack_types": ["generic"],
    "num_blocks": [1],
    "num_block_layers": [4],
    "widths": [512],
    "sharing": [False],
    "expansion_coefficient_lengths": [32],
    # handled already in the TSDS class (i think)
    # "prediction_length": 10,
    # "context_length": 60,
    # ^ Should be between 1-10 times the prediction length (as per pyf.Nbeats docs)
    # "backcast_loss_ratio": #this the paper doesn't say...so setting as default=0 for now
    # "loss": "MASE",                                    # defaults to MASE(), paper in Generic mode used sMAPE, MAPE as well
    
    ### Base Model params
    #"logging_metrics": ['mse','mape','mae'], #for Tsb   # default looks at [SMAPE(), MAE(), RMSE(), MAPE(), MASE()]
    "optimizer": "adam",                                 # NBEATS uses adam
    "weight_decay": 0,                                   # base model default
    
}

# %% [markdown]
# ### Pytorch Lightning Trainer

# %%
pl.seed_everything(42, workers=True)
# Out:
# Global seed set to 42
# 42

# %%
logger = TensorBoardLogger("model_data", name=exp_name, version=None)

# %%
trainer = pl.Trainer(logger=logger,
                     max_epochs=20,
                     default_root_dir="model_data",
                    ) #clipping gradient to prevent explosion?
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs

# %% [markdown]
# ### PYF NBEATS

# %%
# NBEATS paper say they use adam optimizer with default setting, initial lr as 0.001
net = NBeats.from_dataset(training, **params_generic)

# %%
# find optimal learning rate
res = trainer.tuner.lr_find(net, train_dataloader=train_dataloader, val_dataloaders=val_dataloader, min_lr=1e-5)
print(f"suggested learning rate: {res.suggestion()}")
fig = res.plot(show=True, suggest=True)
fig.show()
#use suggested optimal lr
net.hparams.learning_rate = res.suggestion()
# Out:
# Global seed set to 42
# Finding best initial lr: 100%|████████████████| 100/100 [00:25<00:00,  3.97it/s]Restoring states from the checkpoint path at model_data/lr_find_temp_model_a5c673b0-b167-4900-9159-5e9367d03f20.ckpt
# Finding best initial lr: 100%|████████████████| 100/100 [00:25<00:00,  3.96it/s]
# suggested learning rate: 0.19952623149688795

# %% [markdown]
# #### Lol overide

# %%
net.hparams.learning_rate = 0.05

# %% [markdown]
# ### Summary of models' params
# should just be everything in params_generic with learning rate updated

# %%
net.hparams
# Out:
# "backcast_loss_ratio":           0.0
# "context_length":                30
# "dropout":                       0.1
# "expansion_coefficient_lengths": [32]
# "learning_rate":                 0.05
# "log_gradient_flow":             False
# "log_interval":                  -1
# "log_val_interval":              -1
# "logging_metrics":               ModuleList(
#   (0): SMAPE()
#   (1): MAE()
#   (2): RMSE()
#   (3): MAPE()
#   (4): MASE()
# )
# "loss":                          MASE()
# "monotone_constaints":           {}
# "num_block_layers":              [4]
# "num_blocks":                    [1]
# "optimizer":                     adam
# "optimizer_params":              None
# "output_transformer":            EncoderNormalizer()
# "prediction_length":             10
# "reduce_on_plateau_min_lr":      1e-05
# "reduce_on_plateau_patience":    1000
# "sharing":                       [False]
# "stack_types":                   ['generic']
# "weight_decay":                  0
# "widths":                        [512]

# %%
net.summarize()
# Out:
#   | Name            | Type       | Params
# -----------------------------------------------
# 0 | loss            | MASE       | 0
# 1 | logging_metrics | ModuleList | 0
# 2 | net_blocks      | ModuleList | 837 K
# -----------------------------------------------
# 837 K     Trainable params
# 0         Non-trainable params
# 837 K     Total params
# 3.352     Total estimated model params size (MB)

# %%
trainer.fit(
    net,
    train_dataloader=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
#   | Name            | Type       | Params
# -----------------------------------------------
# 0 | loss            | MASE       | 0
# 1 | logging_metrics | ModuleList | 0
# 2 | net_blocks      | ModuleList | 837 K
# -----------------------------------------------
# 837 K     Trainable params
# 0         Non-trainable params
# 837 K     Total params
# 3.352     Total estimated model params size (MB)
# Global seed set to 42
# Epoch 0:  99%|▉| 134/135 [00:33<00:00,  3.95it/s, loss=0.736, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 0: 100%|█| 135/135 [00:33<00:00,  3.98it/s, loss=0.736, v_num=1, train_los
# Epoch 1:  99%|▉| 134/135 [00:34<00:00,  3.91it/s, loss=0.735, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 1: 100%|█| 135/135 [00:34<00:00,  3.94it/s, loss=0.735, v_num=1, train_los
# Epoch 2:  99%|▉| 134/135 [00:33<00:00,  3.95it/s, loss=0.735, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 2: 100%|█| 135/135 [00:33<00:00,  3.98it/s, loss=0.735, v_num=1, train_los
# Epoch 3:  99%|▉| 134/135 [00:34<00:00,  3.91it/s, loss=0.732, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 3: 100%|█| 135/135 [00:34<00:00,  3.93it/s, loss=0.732, v_num=1, train_los
# Epoch 4:  99%|▉| 134/135 [00:34<00:00,  3.85it/s, loss=0.736, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 4: 100%|█| 135/135 [00:34<00:00,  3.87it/s, loss=0.736, v_num=1, train_los
# Epoch 5:  99%|▉| 134/135 [00:34<00:00,  3.92it/s, loss=0.736, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 5: 100%|█| 135/135 [00:34<00:00,  3.95it/s, loss=0.736, v_num=1, train_los
# Epoch 6:  99%|▉| 134/135 [00:34<00:00,  3.92it/s, loss=0.737, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 6: 100%|█| 135/135 [00:34<00:00,  3.94it/s, loss=0.737, v_num=1, train_los
# Epoch 7:  99%|▉| 134/135 [00:34<00:00,  3.90it/s, loss=0.741, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 7: 100%|█| 135/135 [00:34<00:00,  3.92it/s, loss=0.741, v_num=1, train_los
# Epoch 8:  99%|▉| 134/135 [00:34<00:00,  3.93it/s, loss=0.732, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 8: 100%|█| 135/135 [00:34<00:00,  3.96it/s, loss=0.732, v_num=1, train_los
# Epoch 9:  99%|▉| 134/135 [00:34<00:00,  3.92it/s, loss=0.737, v_num=1, train_los
# Validating: 0it [00:00, ?it/s]
# Epoch 9: 100%|█| 135/135 [00:34<00:00,  3.95it/s, loss=0.737, v_num=1, train_los
# Epoch 10:  99%|▉| 134/135 [00:34<00:00,  3.90it/s, loss=0.735, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 10: 100%|█| 135/135 [00:34<00:00,  3.92it/s, loss=0.735, v_num=1, train_lo
# Epoch 11:  99%|▉| 134/135 [00:34<00:00,  3.94it/s, loss=0.742, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 11: 100%|█| 135/135 [00:34<00:00,  3.97it/s, loss=0.742, v_num=1, train_lo
# Epoch 12:  99%|▉| 134/135 [00:34<00:00,  3.93it/s, loss=0.736, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 12: 100%|█| 135/135 [00:34<00:00,  3.95it/s, loss=0.736, v_num=1, train_lo
# Epoch 13:  99%|▉| 134/135 [00:34<00:00,  3.91it/s, loss=0.738, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 13: 100%|█| 135/135 [00:34<00:00,  3.94it/s, loss=0.738, v_num=1, train_lo
# Epoch 14:  99%|▉| 134/135 [00:34<00:00,  3.93it/s, loss=0.737, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 14: 100%|█| 135/135 [00:34<00:00,  3.96it/s, loss=0.737, v_num=1, train_lo
# Epoch 15:  99%|▉| 134/135 [00:34<00:00,  3.94it/s, loss=0.739, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 15: 100%|█| 135/135 [00:34<00:00,  3.97it/s, loss=0.739, v_num=1, train_lo
# Epoch 16:  99%|▉| 134/135 [00:34<00:00,  3.91it/s, loss=0.738, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 16: 100%|█| 135/135 [00:34<00:00,  3.94it/s, loss=0.738, v_num=1, train_lo
# Epoch 17:  99%|▉| 134/135 [00:35<00:00,  3.78it/s, loss=0.739, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 17: 100%|█| 135/135 [00:35<00:00,  3.80it/s, loss=0.739, v_num=1, train_lo
# Epoch 18:  99%|▉| 134/135 [00:35<00:00,  3.79it/s, loss=0.732, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 18: 100%|█| 135/135 [00:35<00:00,  3.82it/s, loss=0.732, v_num=1, train_lo
# Epoch 19:  99%|▉| 134/135 [00:35<00:00,  3.81it/s, loss=0.736, v_num=1, train_lo
# Validating: 0it [00:00, ?it/s]
# Epoch 19: 100%|█| 135/135 [00:35<00:00,  3.83it/s, loss=0.736, v_num=1, train_lo
# Epoch 19: 100%|█| 135/135 [00:35<00:00,  3.83it/s, loss=0.736, v_num=1, train_lo

# %% [markdown]
# # Evaluate Results

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_model = NBeats.load_from_checkpoint(best_model_path)

# %%
# Predicting on validation set
actuals = torch.cat([y[0] for x, y in iter(val_dataloader)])
predictions = best_model.predict(val_dataloader)
(actuals - predictions).abs().mean()
# Out:
# tensor(2.3186e-05)

# %%
# look at random samples in validation set prediction
raw_predictions, x = best_model.predict(val_dataloader, mode="raw", return_x=True)

# %%
len(x), len(raw_predictions)
# Out:
# (11, 5)

# %%
# this encoder decoder length thing is confusing me... but yeah 41 is magic number for len(val_set)==50

# %%
for idx in range(41):  # plot 10 examples
    best_model.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True);

# %%
best_model.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True).savefig('example_pred.png')

# %% [markdown]
# ### Predict on testing dataset

# %%
os.getcwd()
# Out:
# '/Users/dan/Desktop/projects/uexp/ue/experiments/dan'

# %%
os.mkdir("experiment_plots")
